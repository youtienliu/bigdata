# %% [markdown]
# <a href="https://colab.research.google.com/github/youtienliu/bigdata/blob/main/0330_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("rJava")
install.packages("jiebaR")
install.packages("tmcn")
install.packages("dplyr")
install.packages("lubridate")
install.packages("stringr")
install.packages("wordcloud")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘jiebaRD’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("wordcloud2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("Rwordseg", repos = "https://tw.news.yahoo.com/news/%E6%A1%83%E5%9C%92%E5%A4%A7%E6%BD%AD%E8%97%BB%E7%A4%81%E7%88%AD%E8%AD%B0%E4%BA%8B%E4%BB%B6%E6%87%B6%E4%BA%BA%E5%8C%85%EF%BC%81%E7%94%9F%E6%85%8B%E4%BB%8B%E7%B4%B9%E3%80%81%E5%85%AC%E6%8A%95%E9%80%A3%E7%BD%B2%E3%80%81%E7%B6%93%E6%BF%9F%E9%83%A8%E5%9B%9E%E6%87%89%E4%B8%80%E6%AC%A1%E7%9C%8B%E6%87%82-101730886.html")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in gzfile(file, "rb"):
# “cannot open compressed file '/tmp/RtmpchP9Gf/repos_https://tw.news.yahoo.com/news/%E6%A1%83%E5%9C%92%E5%A4%A7%E6%BD%AD%E8%97%BB%E7%A4%81%E7%88%AD%E8%AD%B0%E4%BA%8B%E4%BB%B6%E6%87%B6%E4%BA%BA%E5%8C%85%EF%BC%81%E7%94%9F%E6%85%8B%E4%BB%8B%E7%B4%B9%E3%80%81%E5%85%AC%E6%8A%95%E9%80%A3%E7%BD%B2%E3%80%81%E7%B6%93%E6%BF%9F%E9%83%A8%E5%9B%9E%E6%87%89%E4%B8%80%E6%AC%A1%E7%9C%8B%E6%87%82-101730886.html/src/contrib.rds', probable reason 'No such file or directory'”
# Warning message:
# ...

# %%
library(dplyr)
library(lubridate)
library(stringr)
library(jiebaR)
library(wordcloud)
library(wordcloud2)
# Out:
# Loading required package: jiebaRD
#
# Loading required package: RColorBrewer

# %%
content <- "位於桃園觀音的大潭藻礁，是全球少數僅存的現生淺海藻礁，至少歷時5000至7500年才得以形成，豐富生態養育近百種生物，包括保育類的柴山多杯孔珊瑚、綠蠵龜、台灣白海豚等，獲國際保育組織「Mission Blue」列為東亞第一個生態希望熱點。為了實現非核家園、空污減煤的能源轉型，經濟部規畫2025年天然氣發電占比要提高至50%，並委由中油於桃園觀塘工業區外海興建天然氣接收站，預計填海造陸77公頃。此舉隨即引發環團強烈反彈，指控中油三接工程將帶來凸堤效應，恐導致現存的藻礁海岸全面受害，特有生物保育中心副研究員劉靜榆更直言，藻礁等於是「被判了死刑」。此外，三接工程的環評案先前還曾傳出密集開會、強行通過，2018年時任行政院長賴清德被批評「拿觀塘換深澳說」、以及桃園市長鄭文燦「政策髮夾彎」等爭議事件。珍愛藻礁公投領銜人潘忠政控訴，為了護航中油三接案開發，大潭藻礁一直無法依「文化資產保存法」列為自然地景，且在環團、在地居民、專家學者多年的抗爭下，仍舊未能擋下開發的腳步，因此發起公投案，希望喚起社會更多關注。針對環團發動搶救藻礁公投，經濟部長王美花回應，開發案採三階段開發，且開發面積縮小至十分之一，全部避開藻礁敏感區域；中油則強調，三接的施工計畫已環評審議通過，依法取得開發許可，並採用「迴避替代修正方案」，避開藻礁敏感區域，更未開發有「粉紅藻礁」生態的保留區，若依照環團要求放棄目前進度，供氣時間將從明年延後11年。"

# %%
content
# Out:
# [1] "位於桃園觀音的大潭藻礁，是全球少數僅存的現生淺海藻礁，至少歷時5000至7500年才得以形成，豐富生態養育近百種生物，包括保育類的柴山多杯孔珊瑚、綠蠵龜、台灣白海豚等，獲國際保育組織「Mission Blue」列為東亞第一個生態希望熱點。為了實現非核家園、空污減煤的能源轉型，經濟部規畫2025年天然氣發電占比要提高至50%，並委由中油於桃園觀塘工業區外海興建天然氣接收站，預計填海造陸77公頃。此舉隨即引發環團強烈反彈，指控中油三接工程將帶來凸堤效應，恐導致現存的藻礁海岸全面受害，特有生物保育中心副研究員劉靜榆更直言，藻礁等於是「被判了死刑」。此外，三接工程的環評案先前還曾傳出密集開會、強行通過，2018年時任行政院長賴清德被批評「拿觀塘換深澳說」、以及桃園市長鄭文燦「政策髮夾彎」等爭議事件。珍愛藻礁公投領銜人潘忠政控訴，為了護航中油三接案開發，大潭藻礁一直無法依「文化資產保存法」列為自然地景，且在環團、在地居民、專家學者多年的抗爭下，仍舊未能擋下開發的腳步，因此發起公投案，希望喚起社會更多關注。針對環團發動搶救藻礁公投，經濟部長王美花回應，開發案採三階段開發，且開發面積縮小至十分之一，全部避開藻礁敏感區域；中油則強調，三接的施工計畫已環評審議通過，依法取得開發許可，並採用「迴避替代修正方案」，避開藻礁敏感區域，更未開發有「粉紅藻礁」生態的保留區，若依照環團要求放棄目前進度，供氣時間將從明年延後11年。"

# %%
cutter <- worker(bylines = F) #

# %%
cutter[content]
# Out:
#   [1] "位於"     "桃園"     "觀音"     "的"       "大潭"     "藻礁"
#   [7] "是"       "全球"     "少數"     "僅存"     "的"       "現生"
#  [13] "淺"       "海藻"     "礁"       "至少"     "歷時"     "5000"
#  [19] "至"       "7500"     "年"       "才"       "得以"     "形成"
#  [25] "豐富"     "生態"     "養育"     "近"       "百種"     "生物"
#  [31] "包括"     "保育"     "類的"     "柴山"     "多杯"     "孔"
#  [37] "珊瑚"     "綠"       "蠵"       "龜"       "台"       "灣"
#  [43] "白海豚"   "等"       "獲"       "國際"     "保育"     "組織"
#  [49] "Mission"  "Blue"     "列"       "為"       "東亞"     "第一個"
#  [55] "生態"     "希望"     "熱點"     "為"       "了"       "實現"
#  [61] "非核"     "家園"     "空"       "污"       "減"       "煤"
#  [67] "的"       "能源"     "轉型"     "經濟部"   "規畫"     "2025"
#  [73] "年"       "天然氣"   "發電"     "占"       "比要"     "提高"
#  [79] "至"       "50"       "並委由"   "中油"     "於"       "桃園"
#  [85] "觀塘"     "工業區"   "外海"     "興建"     "天然氣"   "接收站"
#  [91] "預計"     "填"       "海造陸"   "77"       "公頃"     "此舉"
# ...

# %%
new_words <- c("藻礁","開發","中油","保育","桃園","生態","文化")
for (i in 1:length(new_words)) {
  new_user_word(cutter, new_words[i])
}

# %%
content <- str_remove_all(content, "[0-9a-zA-Z]+?")

# %%
cutter[content]
# Out:
#   [1] "位於"     "桃園"     "觀音"     "的"       "大潭"     "藻礁"
#   [7] "是"       "全球"     "少數"     "僅存"     "的"       "現生"
#  [13] "淺海"     "藻礁"     "至少"     "歷時"     "至"       "年"
#  [19] "才"       "得以"     "形成"     "豐富"     "生態"     "養育"
#  [25] "近"       "百種"     "生物"     "包括"     "保育"     "類的"
#  [31] "柴山"     "多杯"     "孔"       "珊瑚"     "綠"       "蠵"
#  [37] "龜"       "台"       "灣"       "白海豚"   "等"       "獲"
#  [43] "國際"     "保育"     "組織"     "列"       "為"       "東亞"
#  [49] "第一個"   "生態"     "希望"     "熱點"     "為"       "了"
#  [55] "實現"     "非核"     "家園"     "空"       "污"       "減"
#  [61] "煤"       "的"       "能源"     "轉型"     "經濟部"   "規畫"
#  [67] "年"       "天然氣"   "發電"     "占"       "比要"     "提高"
#  [73] "至"       "並委由"   "中油"     "於"       "桃園"     "觀塘"
#  [79] "工業區"   "外海"     "興建"     "天然氣"   "接收站"   "預計"
#  [85] "填"       "海造陸"   "公頃"     "此舉"     "隨即"     "引發"
#  [91] "環團"     "強烈"     "反彈"     "指控"     "中油"     "三接"
#  [97] "工程"     "將"       "帶來"     "凸堤"     "效應"     "恐"
# ...

# %%
new_words <- c("藻礁","開發","中油","保育","桃園","生態","文化","三接")
writeLines(new_words, "new_words.txt")

# %%
stop_words <- c("在","之","更","個","未","而","也","與","的","才","是","了","為","年","下","列","且","三","案","將","至","等")
writeLines(stop_words, "stop_words.txt")

# %%
cutter <- worker(user = "new_words.txt", stop_word = "stop_words.txt", bylines = FALSE)

# %%
seg_words <- cutter[content]

# %%
seg_words
# Out:
#   [1] "位於"     "桃園"     "觀音"     "大潭"     "藻礁"     "全球"
#   [7] "少數"     "僅存"     "現生"     "淺海"     "藻礁"     "至少"
#  [13] "歷時"     "得以"     "形成"     "豐富"     "生態"     "養育"
#  [19] "近"       "百種"     "生物"     "包括"     "保育"     "類的"
#  [25] "柴山"     "多杯"     "孔"       "珊瑚"     "綠"       "蠵"
#  [31] "龜"       "台"       "灣"       "白海豚"   "獲"       "國際"
#  [37] "保育"     "組織"     "東亞"     "第一個"   "生態"     "希望"
#  [43] "熱點"     "實現"     "非核"     "家園"     "空"       "污"
#  [49] "減"       "煤"       "能源"     "轉型"     "經濟部"   "規畫"
#  [55] "天然氣"   "發電"     "占"       "比要"     "提高"     "並委由"
#  [61] "中油"     "於"       "桃園"     "觀塘"     "工業區"   "外海"
#  [67] "興建"     "天然氣"   "接收站"   "預計"     "填"       "海造陸"
#  [73] "公頃"     "此舉"     "隨即"     "引發"     "環團"     "強烈"
#  [79] "反彈"     "指控"     "中油"     "三接"     "工程"     "帶來"
#  [85] "凸堤"     "效應"     "恐"       "導致"     "現存"     "藻礁"
#  [91] "海岸"     "全面"     "受害"     "特有"     "生物"     "保育"
#  [97] "中心"     "副研究員" "劉靜"     "榆"       "直言"     "藻礁"
# ...

# %%
txt_freq <- freq(seg_words)

# %%
txt_freq <- arrange(txt_freq, desc(freq))

# %%
head(txt_freq)
# Out:
#   char freq
# 1 藻礁 10
# 2 開發  7
# 3 三接  4
# 4 中油  4
# 5 環團  4
# 6 生態  3

# %%
par(family = ("Microsoft YaHei"))

# %%
wordcloud(txt_freq$char, txt_freq$freq, min.freq = 2, random.order = F, ordered.colors = F, colors = rainbow(nrow(txt_freq)))
# Out:
# plot without title

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’

# %%
library(showtext)
# Out:
# Loading required package: sysfonts
#
# Loading required package: showtextdb

# %%
showtext.auto(enable = TRUE)
# Out:
# 'showtext.auto()' is now renamed to 'showtext_auto()'
# The old version still works, but consider using the new function in future code
